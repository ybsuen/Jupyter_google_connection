# %%
# %%time
import requests
import csv
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
from random import randint
from time import time

# quote_page = requests.get('http://startupbeat.hkej.com/?tag=fintech&paged=1') 
# soup = BeautifulSoup(quote_page.text,'html.parser')

header = ['page #','title','url','details','post date']
data = []
# Display and store away 2 pages of scrapped data from startupbeat.hkej.com
for i in range(1,4):
    quote_page = requests.get('http://startupbeat.hkej.com/?tag=fintech&paged='+str(i)) 
    sleep(randint(8,15))
    print("\n***** Page " + str(i) +" in action *****")
    soup = BeautifulSoup(quote_page.content,'html.parser')
    
    for article in soup.find_all("div", attrs={"class":"archive-text"}):
    # for article in soup.find_all('div',class_='archive-text'):
         page_no = str(i)
         title = article.a.text.encode('utf-8').strip()
         decoded_title = title.decode('utf-8')
         url = article.a.get('href')
         details = article.p.text.encode('utf-8').strip()
         decoded_details = details.decode('utf-8')
         post_date = article.div.ul.li.text
         print(decoded_title)
         print(url)
         print(decoded_details)
         print(post_date)
         data.append((page_no, decoded_title, url, decoded_details, post_date))
        
df = pd.DataFrame(data,
  columns = header
)
df.to_csv('projects/startup_beat_data_1.csv', sep='\t', encoding='utf-8')
# Out:
# ***** Page 1 in action *****
# 流動支付多重驗證保安全 (方保僑)
# http://startupbeat.hkej.com/?p=64743
# 使用WeChat Pay HK的服務時均會提供3層驗證，用戶須輸入登入密碼驗證，再輸入相關信用卡或銀行卡資料，以及信用卡驗證碼，並必須輸入6位數字付款密碼來進行支付，而其隱私政策也通過TRUSTe認證。
# Posted October 15, 2018
# 107萬用戶登記「轉數快」 手機佔七成
# http://startupbeat.hkej.com/?p=64514
# 金管局昨公布，自9月17日至本月7日止約3周，快速支付系統「轉數快」共錄得107.1萬個登記，較9月底的45.6萬個登記增逾1倍，以手機號碼登記繼續成為主流，有75.7萬個用戶。
# Posted October 9, 2018
# FinTech初創晤金管 冀改善開戶難
# http://startupbeat.hkej.com/?p=64440
# 金管局於2016年推出3項指引，便利中小企在銀行開戶，惟至今仍有不少企業面對在銀行開戶困難的問題，較嚴重的包括涉及不少現金往來的找換店，以及難有詳盡財務紀錄的金融科技初創公司。
# Posted October 8, 2018
# Mastercard夥教育App拓電子交費
# http://startupbeat.hkej.com/?p=64357
# 本港金融業陸續加大對金融科技的應用，信用卡公司Mastercard亦宣布，與本地教育應用程式GRWTH合作，推出電子交學校雜費功能，首批參與的包括中學、小學及幼稚園等10間學校。
# Posted October 5, 2018
# FPS轉數有幾快？ (方保僑)
# http://startupbeat.hkej.com/?p=64353
# 目前有21間銀行（包括大部分零售銀行）以及10間儲值支付工具已經參與了「轉數快」系統，市民可以通過參與銀行及儲值支付工具營運商的手機程式，在「轉數快」登記手機號碼或電郵地址作為收款賬戶代碼。
# Posted October 5, 2018
# 轉數快助港邁向無現金城市 (香港智慧城市聯盟陳家豪)
# http://startupbeat.hkej.com/?p=64342
# 市民只須以手機號碼或電郵識別收款人，即可藉「轉數快」跨銀行實時清算。《信報》StartupBeat請來香港智慧城市聯盟金融科技委員會主席陳家豪，分析它如何助港邁向無現金城市。
# Posted October 5, 2018
# 渣打參與大灣區區塊鏈平台
# http://startupbeat.hkej.com/?p=64330
# 渣打近日參與由深圳人行牽頭推出的大灣區貿易金融區塊鏈平台，為唯一的外資參與行，初期用於應收賬款貿易融資項目。安必杰透露，區塊鏈為新技術應用，每個平台會先以最簡單產品作試點。
# Posted October 4, 2018
# 開放政策是提高城市競爭力的主要手段 (陳家豪)
# http://startupbeat.hkej.com/?p=64275
# 二十年轉眼就過去了，八達通依然故我。 當全球地鐵及公交乘客已經紛紛採用不同的國際支付工具如Visa、Master Card、銀聯、微信、支付寶甚至 ApplePay 及 Andriod Pay 的時候，香港卻停留在單一機制的基礎上原地踏步。
# Posted October 3, 2018
# 「轉數快」鞏固港金融中心地位 (鄧淑明博士)
# http://startupbeat.hkej.com/?p=64259
# 快速支付系統「轉數快」解除不同銀行及電子錢包系統之間轉賬的阻隔，年中無休實時交收清算，市民只須以手機號碼或電郵地址作為收款人識別代號，便可即時跨銀行及SVF營運商的資金轉賬。
# Posted October 3, 2018
# 轉數快首日交易逾5萬宗 涉款2億
# http://startupbeat.hkej.com/?p=64212
# 金管局快速支付系統「轉數快」周日（9月30日）正式啟用，該局表示首天運作大致暢順，並錄得逾5萬宗交易（包括轉賬及扣賬），經「轉數快」系統進行的交易金額超過2億元，當中人民幣佔160萬元。
# Posted October 2, 2018
#
# ***** Page 2 in action *****
# 行業趨波動 日韓市場關鍵
# http://startupbeat.hkej.com/?p=64206
# LINE Tech Plus 總監及加密貨幣交易所BITBOX項目經理Edward Lee 接受訪問時稱，「加密貨幣仍處於早期階段，我們預計市場在穩定之前，會經歷與其他行業相同的起伏。」
# Posted October 2, 2018
# LINE力谷代幣經濟 來港設創投基金攻區塊鏈
# http://startupbeat.hkej.com/?p=64198
# 加密貨幣炒賣潮近月顯著降溫，社交網絡巨擘LINE卻成立加密貨幣創投基金unblock ventures，透過約7800萬港元資本額，專門投資區塊鏈初創。
# Posted October 2, 2018
# 轉數快獲46萬登記 周日開通
# http://startupbeat.hkej.com/?p=64162
# 金管局推出的快速支付系統「轉數快」周日（30日）開始啟用，該局公布由9月17日宣布推出起，累計有45.6萬用戶登記，中銀香港（02388）預期登記數量可望突破百萬個。
# Posted September 29, 2018
# 轉數快，轉數更快 (柏拉圖)
# http://startupbeat.hkej.com/?p=63986
# FPS 是金管局在香港推廣 FinTech 的其中一個重要項目，說穿了就是將本來香港銀行界款項流通的各種壁壘打破。作為一個標準的香港人，另一個必然會問的問題就是：這樣跨銀行付款需要收費嗎？
# Posted September 29, 2018
# Stripe估值翻倍
# http://startupbeat.hkej.com/?p=64141
# 美國初創企業網上支付平台Stripe周三表示，已獲得新一輪2.45億美元融資，將用作拓展海外市場及吸引更多大型客戶，並令公司估值增至202.5億美元（約1580億港元），較2016年的92億美元翻逾一倍。
# Posted September 28, 2018
# 比特大陸來港同股不同權上市
# http://startupbeat.hkej.com/?p=64048
# 據外電8月時報道，比特大陸擬來港上市集資至少30億美元（約234億港元）。而除比特大陸外，另外兩間礦機生產商嘉楠耘智（Canaan Inc.）及億邦國際，亦先後於今年5月及6月已經提交上市申請，但至今未有進展。
# Posted September 27, 2018
# 長和夥WeLab拓消費分期貸款
# http://startupbeat.hkej.com/?p=64043
# 長和（00001）與金融科技公司WeLab合作，在旗下的3Shop及豐澤引入消費分期貸款服務，客戶購物付款時可選用WeLab旗下WeLend的分期貸款，年期可長達60個月，甚至可即時提取額外現金。
# Posted September 27, 2018
# 「轉數快」打通任督二脈 (方保僑)
# http://startupbeat.hkej.com/?p=63967
# 金管局去年9月宣布推出快速支付系統，「轉數快」每日24小時、每星期7日全天候運作，提供平台全面接通不同銀行及儲值支付工具營運商，讓市民可以隨時隨地在跨銀行及儲值支付工具進行即時資金轉賬。
# Posted September 26, 2018
# 龐氏騙局2.0 (老占)
# http://startupbeat.hkej.com/?p=63931
# 如果P2P平台忘記了金融科技的初衷，反而只做流量生意，一心只想透過大規模的網絡行銷獲取用戶，把用戶投資的理財資金變成平台的資金池，這樣的平台本質上就是龐氏騙局2.0。
# Posted September 24, 2018
# TNG Wallet加盟「轉數快」 零手續費實時轉賬
# http://startupbeat.hkej.com/?p=63876
# 香港金融科技集團TNG （Asia）Limited宣布，其電子錢包平台TNG Wallet即將開放予香港金融管理局牽頭的快速支付系統「轉數快」登記渠道，提供$0手續費的跨平台實時轉賬服務。
# Posted September 21, 2018
#
# ***** Page 3 in action *****
# 螞蟻金服：未來聚焦五大技術
# http://startupbeat.hkej.com/?p=63847
# 阿里將推出兩款新的服務型機器人，阿里人工智能實驗室總經理陳麗娟說，太空蛋用於酒店，回應住客各種問題，提供物品配送，預計10月面世。太空梭則用於醫院，具有60個可彈出藥倉，協助醫護人員工作。
# Posted September 21, 2018
# 日加密幣交易所遭黑客盜竊   Zaif損失4.7億管理層辭職
# http://startupbeat.hkej.com/?p=63837
# Zaif系統在9月14日（上周五）下午5點至7點左右被非法入侵其「熱錢包」，偷去比特幣、比特幣現金和萌奈幣（Monacoin）3種加密貨幣。「熱錢包」與互聯網連接，遭非法入侵的機會比沒有連接的「冷錢包」高。
# Posted September 21, 2018
# 「薯片叔叔」搞初創
# http://startupbeat.hkej.com/?p=63795
# 前財政司司長曾俊華昨日在社交網站宣布成立另一初創企業「薯片叔叔共創社」，凝聚不同地方、界別、階層、年齡和專長的人士，「就某些社會議題一同思考」。
# Posted September 20, 2018
# WeLab虛擬銀行搶年輕客 陳家強任非執行主席
# http://startupbeat.hkej.com/?p=63716
# 上月提交虛擬銀行申請的WeLab，有信心成為首批獲金管局發牌照的公司，創始人兼首席執行官龍沛智表示，日後虛擬銀行會利用金融科技，由現時網上貸款業務，擴展至存款、支付及理財業務，會做到基本銀行服務全覆蓋。
# Posted September 19, 2018
# 「轉數快」逾10商戶即採用 跨行跨錢包即時轉賬創全球先河
# http://startupbeat.hkej.com/?p=63643
# 金管局總裁陳德霖表示，「轉數快」月底全面啟用和開通，登記過程只是方便市民作為收款人，至於付款則毋須登記，用戶只要登入銀行或電子錢包應用程式使用轉賬功能，便可以享受到「轉數快」帶來的便利。
# Posted September 18, 2018
# 金管「轉數快」啟動 1萬免雙認證
# http://startupbeat.hkej.com/?p=63586
# 金管局牽頭的「快速支付系統（FPS）」，今日開始接受登記，取名為「轉數快」，已登記的用戶將可透過手機錢包及網上銀行等方式，使用跨銀行及SVF即時轉賬。使用「轉數快」轉賬普遍不用收費，1萬元以下毋須雙重認證。
# Posted September 17, 2018
# 金管暑假創業營 大專生快閃遊「中國矽谷」 (凌通)
# http://startupbeat.hkej.com/?p=63513
# 全世界對金融科技界人才極之渴求，金管局金融科技促進辦公室（FFO）今年暑假就做了兩大項「暑期作業」，讓數十名大專學生有機會參與FFO有份安排的兩場金融科技人才培育活動，進一步裝備自己。
# Posted September 14, 2018
# 貿易融資區塊鏈平台月內推出
# http://startupbeat.hkej.com/?p=63459
# 金管局金融科技總監周文正表示，由7家銀行發起的貿易融資區塊鏈平台將於本月稍後推出，除發起銀行外，未來會有更多銀行參與。他又提到，有關快速支付系統的測試順利，將如期本月公布細節。
# Posted September 13, 2018
# 港首家網上壽險Blue主打免佣
# http://startupbeat.hkej.com/?p=63453
# Blue為新成立品牌，投資方騰訊佔20%，英傑華集團（Aviva）及高瓴資本（Hillhouse Capital）則各佔40%，實際管理保單的為英傑華香港。Blue行政總裁孔德秋表示，隨着科技發展，網上銷售金融產品將成為新趨勢。
# Posted September 13, 2018
# 金管局巴西央行 聯手拓金融科技
# http://startupbeat.hkej.com/?p=63354
# 香港金管局與巴西中央銀行9月9日於瑞士巴塞爾簽署《合作協議》，加強兩央行在金融科技上的合作，以鼓勵和促進兩地金融服務創新，並支援創新金融業務進軍對方市場。
# Posted September 11, 2018
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/formats/format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'projects/startup_beat_data_1.csv'
